# %%
import nltk
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec

nltk.download("punkt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import nltk
#       2 from nltk.tokenize import word_tokenize
# ----> 3 from gensim.models import Word2Vec
#       5 nltk.download("punkt")
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\gensim\matutils.py:1034
#    1029     return 1. - float(len(set1 & set2)) / float(union_cardinality)
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1036 except ImportError:
#    1037     def logsumexp(x):
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\gensim\_matutils.pyx:1, in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
sentences = [
    "I love natural language processing",
    "I love machine learning",
    "I enjoy deep learning",
    "Natural language processing is a part of artificial intelligence",
    "Machine learning is used in artificial intelligence",
    "Deep learning is a branch of machine learning",
    "I love learning about artificial intelligence"
]

# %%
tokenized_sentences = []

for sentence in sentences:
    tokens = word_tokenize(sentence.lower())
    tokenized_sentences.append(tokens)

print(tokenized_sentences)
# Out:
# [['i', 'love', 'natural', 'language', 'processing'], ['i', 'love', 'machine', 'learning'], ['i', 'enjoy', 'deep', 'learning'], ['natural', 'language', 'processing', 'is', 'a', 'part', 'of', 'artificial', 'intelligence'], ['machine', 'learning', 'is', 'used', 'in', 'artificial', 'intelligence'], ['deep', 'learning', 'is', 'a', 'branch', 'of', 'machine', 'learning'], ['i', 'love', 'learning', 'about', 'artificial', 'intelligence']]

# %%
model = Word2Vec(
    sentences=tokenized_sentences,
    vector_size=100,
    window=3,
    min_count=1,
    workers=4,
    sg=1
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = Word2Vec(
#       2     sentences=tokenized_sentences,
#       3     vector_size=100,
#       4     window=3,
#       5     min_count=1,
#       6     workers=4,
#       7     sg=1
#       8 )
#
# NameError: name 'Word2Vec' is not defined

# %%
vector = model.wv["learning"]
print(vector)
print(len(vector))

# %%
similar_words = model.wv.most_similar("learning", topn=5)

for word, score in similar_words:
    print(word, score)

# %%
similarity = model.wv.similarity("machine", "learning")
print(similarity)

# %%
model.save("word2vec_model.model")

# %%
loaded_model = Word2Vec.load("word2vec_model.model")

print(loaded_model.wv.most_similar("learning"))

# %%
loaded_model = Word2Vec.load("word2vec_model.model")

print(loaded_model.wv.most_similar("learning"))

# %%
cbow_model = Word2Vec(
    sentences=tokenized_sentences,
    vector_size=100,
    window=3,
    min_count=1,
    workers=4,
    sg=0
)

# %%
skipgram_model = Word2Vec(
    sentences=tokenized_sentences,
    vector_size=100,
    window=3,
    min_count=1,
    workers=4,
    sg=1
)

# %%
print("CBOW:")
print(cbow_model.wv.most_similar("learning", topn=5))

print("\nSkip-Gram:")
print(skipgram_model.wv.most_similar("learning", topn=5))

# %%
import numpy as np

def load_glove_model(file_path):
    glove_model = {}

    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            glove_model[word] = vector

    return glove_model

glove = load_glove_model("glove.6B.50d.txt")

print("Total words loaded:", len(glove))

# %%
word = "king"

if word in glove:
    print(glove[word])
    print("Vector dimension:", len(glove[word]))
else:
    print("Word not found")

# %%
from numpy.linalg import norm

def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (norm(vec1) * norm(vec2))

word1 = "king"
word2 = "queen"

similarity = cosine_similarity(glove[word1], glove[word2])

print(f"Similarity between {word1} and {word2}: {similarity}")

# %%
def most_similar(word, glove_model, top_n=5):
    if word not in glove_model:
        return f"'{word}' not found in vocabulary."

    target_vector = glove_model[word]
    similarities = {}

    for other_word, other_vector in glove_model.items():
        if other_word != word:
            similarities[other_word] = cosine_similarity(target_vector, other_vector)

    sorted_words = sorted(similarities.items(), key=lambda x: x[1], reverse=True)

    return sorted_words[:top_n]

result = most_similar("king", glove, top_n=5)

for word, score in result:
    print(word, score)

# %%
def analogy(word_a, word_b, word_c, glove_model, top_n=5):
    if word_a not in glove_model or word_b not in glove_model or word_c not in glove_model:
        return "One or more words not found."

    target_vector = glove_model[word_a] - glove_model[word_b] + glove_model[word_c]

    similarities = {}

    for word, vector in glove_model.items():
        if word not in [word_a, word_b, word_c]:
            similarities[word] = cosine_similarity(target_vector, vector)

    sorted_words = sorted(similarities.items(), key=lambda x: x[1], reverse=True)

    return sorted_words[:top_n]

results = analogy("king", "man", "woman", glove)

for word, score in results:
    print(word, score)

# %%
import numpy as np

def sentence_vector_word2vec(sentence, model):
    tokens = word_tokenize(sentence.lower())

    vectors = []

    for token in tokens:
        if token in model.wv:
            vectors.append(model.wv[token])

    if len(vectors) == 0:
        return np.zeros(model.vector_size)

    return np.mean(vectors, axis=0)

sentence = "I love machine learning"

vec = sentence_vector_word2vec(sentence, model)

print(vec)
print("Vector dimension:", len(vec))

# %%
import numpy as np

def sentence_vector_word2vec(sentence, model):
    tokens = word_tokenize(sentence.lower())

    vectors = []

    for token in tokens:
        if token in model.wv:
            vectors.append(model.wv[token])

    if len(vectors) == 0:
        return np.zeros(model.vector_size)

    return np.mean(vectors, axis=0)

sentence = "I love machine learning"

vec = sentence_vector_word2vec(sentence, model)

print(vec)
print("Vector dimension:", len(vec))
